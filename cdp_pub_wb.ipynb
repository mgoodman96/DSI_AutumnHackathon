# %%
#Libraries
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from sodapy import Socrata
from pyensign.events import Event
from pyensign.ensign import Ensign
import json
from cdp_secrets import token,ensign_client,ensign_secret

#Credentials
ensign=Ensign(client_id=ensign_client,client_secret=ensign_secret)

#Event Handling
async def handle_ack(ack):
    ts = datetime.fromtimestamp(ack.committed.seconds + ack.committed.nanos / 1e9)
    print(ts)

async def handle_nack(nack):
    print(f"Could not commit event {nack.id} with error {nack.code}: {nack.error}")

#CDP ETL
class ChicagoTrafficData:
    def __init__(self, token, limit=1000000000):
        self.chicago_url = "data.cityofchicago.org"
        self.vehicle_api_root = "68nd-jvt3"
        self.people_api_root = "u6pd-qa9d"
        self.crash_api_root = "85ca-t3if"
        self.limit = limit
        self.today = datetime.now().strftime("%Y-%m-%d")
        self.yesterday = (datetime.now() - timedelta(days=1)).strftime("%Y-%m-%d")
        self.eighteen_months = (datetime.now() - relativedelta(months=18)).strftime("%Y-%m-%d")
        self.cdp = Socrata(self.chicago_url, token)

    def callAPI(self, root, query_filter):
        results = self.cdp.get(root, query=query_filter)
        return pd.DataFrame.from_records(results)

    def build_filters(self):
        vehicle_filter = f"""SELECT crash_record_id, crash_date, make, model, vehicle_type 
                             WHERE vehicle_type IS NOT NULL 
                             AND crash_date BETWEEN '{self.yesterday}' AND '{self.today}' 
                             LIMIT {self.limit}"""

        people_filter = f"""SELECT person_id, crash_record_id, crash_date, person_type, age, sex,
                            injury_classification, pedpedal_action, pedpedal_visibility, pedpedal_location
                            WHERE CRASH_DATE BETWEEN '{self.yesterday}' AND '{self.today}' 
                            AND (person_type='PEDESTRIAN' OR person_type='BICYCLE') 
                            LIMIT {self.limit}"""

        crash_filter = f"""SELECT DISTINCT *
                           WHERE crash_date BETWEEN '{self.yesterday}' AND '{self.today}' 
                           LIMIT {self.limit}"""

        return vehicle_filter, people_filter, crash_filter

    def get_data(self):
        vehicle_filter, people_filter, crash_filter = self.build_filters()
        
        people_df = self.callAPI(self.people_api_root, people_filter)
        vehicle_df = self.callAPI(self.vehicle_api_root, vehicle_filter)
        crash_df = self.callAPI(self.crash_api_root, crash_filter)

        return people_df, vehicle_df, crash_df
    
    def merge_data(self, people_df, vehicle_df, crash_df):
        people_vehicle = pd.merge(people_df, vehicle_df[['crash_record_id','make','model','vehicle_type']], on='crash_record_id', how='left')
        crash_pv = pd.merge(people_vehicle, crash_df, on='crash_record_id', how='left')

        return crash_pv

    def fetch_and_export_data(self):
        people_data, vehicle_data, crash_data = self.get_data()
        merged_data = self.merge_data(people_data, vehicle_data, crash_data)
        
        # Convert the DataFrame to a dictionary
        data_dict = merged_data.to_dict(orient='records')
        return data_dict
    

#Run ETL
data_fetcher = ChicagoTrafficData(token)
data_dict = data_fetcher.fetch_and_export_data()

#Load to Ensign
for record in data_dict:
            print(record)
            event = Event(json.dumps(record).encode("utf-8"), mimetype="application/json")
            await ensign.publish('publisher_test', event, on_ack=handle_ack, on_nack=handle_nack)
# Out:
# {'person_id': 'O1678987', 'crash_record_id': '3ae2a0aba323db760ce178a0dc5f2d0bbfa0698e1ca15c76b36598da05485771b3e519b44f8a31595703eb0c7a113438cdf43dafddecd3db8236923ff3cfe85f', 'crash_date_x': '2023-10-10T19:15:00.000', 'person_type': 'BICYCLE', 'age': '15', 'sex': 'F', 'injury_classification': 'NONINCAPACITATING INJURY', 'pedpedal_action': 'CROSSING - AGAINST SIGNAL', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN ROADWAY', 'make': 'TOYOTA', 'model': 'COROLLA', 'vehicle_type': 'PASSENGER', 'crash_date_y': '2023-10-10T19:15:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'NO CONTROLS', 'device_condition': 'NO CONTROLS', 'weather_condition': 'CLEAR', 'lighting_condition': 'DARKNESS, LIGHTED ROAD', 'first_crash_type': 'PEDALCYCLIST', 'trafficway_type': 'FOUR WAY', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T19:20:00.000', 'prim_contributory_cause': 'DISREGARDING TRAFFIC SIGNALS', 'sec_contributory_cause': 'NOT APPLICABLE', 'street_no': '2443', 'street_direction': 'N', 'street_name': 'SACRAMENTO AVE', 'beat_of_occurrence': '1414', 'num_units': '2', 'most_severe_injury': 'NONINCAPACITATING INJURY', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '1', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '19', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.926056903', 'longitude': '-87.702202361', 'location': {'type': 'Point', 'coordinates': [-87.702202360834, 41.926056903368]}, 'intersection_related_i': 'Y', 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678966', 'crash_record_id': 'd54909c9b2dadaf224d2212a4f14ff08a552a1340431511889e1115a37713b8ea0b0be60681fa3c861308eb25de33c66dbbd0ebe46479b778b17466c60e7d4e6', 'crash_date_x': '2023-10-10T18:55:00.000', 'person_type': 'PEDESTRIAN', 'age': nan, 'sex': 'M', 'injury_classification': 'INCAPACITATING INJURY', 'pedpedal_action': 'STANDING IN ROADWAY', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN ROADWAY', 'make': 'FORD', 'model': 'EXPLORER', 'vehicle_type': 'SPORT UTILITY VEHICLE (SUV)', 'crash_date_y': '2023-10-10T18:55:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'NO CONTROLS', 'device_condition': 'NO CONTROLS', 'weather_condition': 'CLEAR', 'lighting_condition': 'DAYLIGHT', 'first_crash_type': 'REAR TO FRONT', 'trafficway_type': 'NOT DIVIDED', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T19:03:00.000', 'prim_contributory_cause': 'EQUIPMENT - VEHICLE CONDITION', 'sec_contributory_cause': 'NOT APPLICABLE', 'street_no': '2348', 'street_direction': 'W', 'street_name': 'ADDISON ST', 'beat_of_occurrence': '1921', 'num_units': '3', 'most_severe_injury': 'INCAPACITATING INJURY', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '1', 'injuries_non_incapacitating': '0', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '18', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.946846401', 'longitude': '-87.687779857', 'location': {'type': 'Point', 'coordinates': [-87.6877798574, 41.946846400996]}, 'intersection_related_i': nan, 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678966', 'crash_record_id': 'd54909c9b2dadaf224d2212a4f14ff08a552a1340431511889e1115a37713b8ea0b0be60681fa3c861308eb25de33c66dbbd0ebe46479b778b17466c60e7d4e6', 'crash_date_x': '2023-10-10T18:55:00.000', 'person_type': 'PEDESTRIAN', 'age': nan, 'sex': 'M', 'injury_classification': 'INCAPACITATING INJURY', 'pedpedal_action': 'STANDING IN ROADWAY', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN ROADWAY', 'make': 'FORD', 'model': 'FOCUS', 'vehicle_type': 'PASSENGER', 'crash_date_y': '2023-10-10T18:55:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'NO CONTROLS', 'device_condition': 'NO CONTROLS', 'weather_condition': 'CLEAR', 'lighting_condition': 'DAYLIGHT', 'first_crash_type': 'REAR TO FRONT', 'trafficway_type': 'NOT DIVIDED', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T19:03:00.000', 'prim_contributory_cause': 'EQUIPMENT - VEHICLE CONDITION', 'sec_contributory_cause': 'NOT APPLICABLE', 'street_no': '2348', 'street_direction': 'W', 'street_name': 'ADDISON ST', 'beat_of_occurrence': '1921', 'num_units': '3', 'most_severe_injury': 'INCAPACITATING INJURY', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '1', 'injuries_non_incapacitating': '0', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '18', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.946846401', 'longitude': '-87.687779857', 'location': {'type': 'Point', 'coordinates': [-87.6877798574, 41.946846400996]}, 'intersection_related_i': nan, 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678893', 'crash_record_id': '26ec797a395b801186c58d574695d459b0a091e5ff873b42456759973982854ee0623428dd02c2a543b974e70080763a77ecc800e9f36626f93aba3833c9c0ec', 'crash_date_x': '2023-10-10T18:27:00.000', 'person_type': 'PEDESTRIAN', 'age': '51', 'sex': 'M', 'injury_classification': 'INCAPACITATING INJURY', 'pedpedal_action': 'CROSSING - WITH SIGNAL', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN CROSSWALK', 'make': 'CHRYSLER', 'model': '200', 'vehicle_type': 'PASSENGER', 'crash_date_y': '2023-10-10T18:27:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'TRAFFIC SIGNAL', 'device_condition': 'FUNCTIONING PROPERLY', 'weather_condition': 'CLEAR', 'lighting_condition': 'DUSK', 'first_crash_type': 'PEDESTRIAN', 'trafficway_type': 'FOUR WAY', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'UNKNOWN', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T18:27:00.000', 'prim_contributory_cause': 'IMPROPER TURNING/NO SIGNAL', 'sec_contributory_cause': 'NOT APPLICABLE', 'street_no': '32', 'street_direction': 'E', 'street_name': 'ONTARIO ST', 'beat_of_occurrence': '1834', 'num_units': '2', 'most_severe_injury': 'INCAPACITATING INJURY', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '1', 'injuries_non_incapacitating': '0', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '3', 'injuries_unknown': '0', 'crash_hour': '18', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.89340183', 'longitude': '-87.626831694', 'location': {'type': 'Point', 'coordinates': [-87.626831694138, 41.893401829586]}, 'intersection_related_i': 'Y', 'photos_taken_i': 'Y', 'crash_date_est_i': nan, 'statements_taken_i': 'Y', 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678960', 'crash_record_id': 'abfb71e29b4384efccb809a32bdf355fa2a513fc1ced892d54567973274af9215e9e27a655fa4f0bf0893830acfa7eda641a81d248781acb01b5bc37d7ab1d49', 'crash_date_x': '2023-10-10T18:03:00.000', 'person_type': 'BICYCLE', 'age': '13', 'sex': 'M', 'injury_classification': 'NONINCAPACITATING INJURY', 'pedpedal_action': 'ENTER FROM DRIVE/ALLEY', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN ROADWAY', 'make': 'JEEP', 'model': 'JEEP', 'vehicle_type': 'PASSENGER', 'crash_date_y': '2023-10-10T18:03:00.000', 'posted_speed_limit': '20', 'traffic_control_device': 'NO CONTROLS', 'device_condition': 'NO CONTROLS', 'weather_condition': 'CLEAR', 'lighting_condition': 'DAYLIGHT', 'first_crash_type': 'PEDALCYCLIST', 'trafficway_type': 'ONE-WAY', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': '$501 - $1,500', 'date_police_notified': '2023-10-10T18:09:00.000', 'prim_contributory_cause': 'FAILING TO YIELD RIGHT-OF-WAY', 'sec_contributory_cause': 'DISTRACTION - FROM INSIDE VEHICLE', 'street_no': '5150', 'street_direction': 'N', 'street_name': 'DRAKE AVE', 'beat_of_occurrence': '1712', 'num_units': '2', 'most_severe_injury': 'NONINCAPACITATING INJURY', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '1', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '18', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.97533179', 'longitude': '-87.717369237', 'location': {'type': 'Point', 'coordinates': [-87.717369237384, 41.97533179005]}, 'intersection_related_i': nan, 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678954', 'crash_record_id': '9a13136a8a4b4ed5e66b0e67013fc43cb0f0a8fe47637d36e29e084449a3168cfe1efcd0eb9396e486c90d99b7c18a9cc0fceb2c55be5aadd47af161b3062300', 'crash_date_x': '2023-10-10T17:45:00.000', 'person_type': 'PEDESTRIAN', 'age': '14', 'sex': 'M', 'injury_classification': 'NONINCAPACITATING INJURY', 'pedpedal_action': 'WITH TRAFFIC', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN CROSSWALK', 'make': 'UNKNOWN', 'model': 'MOTORIZED', 'vehicle_type': 'SPORT UTILITY VEHICLE (SUV)', 'crash_date_y': '2023-10-10T17:45:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'TRAFFIC SIGNAL', 'device_condition': 'FUNCTIONING PROPERLY', 'weather_condition': 'UNKNOWN', 'lighting_condition': 'UNKNOWN', 'first_crash_type': 'PEDESTRIAN', 'trafficway_type': 'NOT DIVIDED', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'UNKNOWN', 'road_defect': 'UNKNOWN', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': 'Y', 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T18:22:00.000', 'prim_contributory_cause': 'UNABLE TO DETERMINE', 'sec_contributory_cause': 'UNABLE TO DETERMINE', 'street_no': '7900', 'street_direction': 'S', 'street_name': 'PULASKI RD', 'beat_of_occurrence': '834', 'num_units': '3', 'most_severe_injury': 'NONINCAPACITATING INJURY', 'injuries_total': '2', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '2', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '17', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.749339', 'longitude': '-87.722052091', 'location': {'type': 'Point', 'coordinates': [-87.722052090915, 41.749339000082]}, 'intersection_related_i': nan, 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678957', 'crash_record_id': '9a13136a8a4b4ed5e66b0e67013fc43cb0f0a8fe47637d36e29e084449a3168cfe1efcd0eb9396e486c90d99b7c18a9cc0fceb2c55be5aadd47af161b3062300', 'crash_date_x': '2023-10-10T17:45:00.000', 'person_type': 'PEDESTRIAN', 'age': '14', 'sex': 'F', 'injury_classification': 'NONINCAPACITATING INJURY', 'pedpedal_action': 'TO/FROM DISABLED VEHICLE', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN CROSSWALK', 'make': 'UNKNOWN', 'model': 'MOTORIZED', 'vehicle_type': 'SPORT UTILITY VEHICLE (SUV)', 'crash_date_y': '2023-10-10T17:45:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'TRAFFIC SIGNAL', 'device_condition': 'FUNCTIONING PROPERLY', 'weather_condition': 'UNKNOWN', 'lighting_condition': 'UNKNOWN', 'first_crash_type': 'PEDESTRIAN', 'trafficway_type': 'NOT DIVIDED', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'UNKNOWN', 'road_defect': 'UNKNOWN', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': 'Y', 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T18:22:00.000', 'prim_contributory_cause': 'UNABLE TO DETERMINE', 'sec_contributory_cause': 'UNABLE TO DETERMINE', 'street_no': '7900', 'street_direction': 'S', 'street_name': 'PULASKI RD', 'beat_of_occurrence': '834', 'num_units': '3', 'most_severe_injury': 'NONINCAPACITATING INJURY', 'injuries_total': '2', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '2', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '17', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.749339', 'longitude': '-87.722052091', 'location': {'type': 'Point', 'coordinates': [-87.722052090915, 41.749339000082]}, 'intersection_related_i': nan, 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678794', 'crash_record_id': '569483d29ad72b58835f51b3b2dc56f86e4ca50085bf21a1c8c5cba432dd3786f49840666ee226cc0115a421085604b6f381f1c3744a9780efb9541289fc6b0f', 'crash_date_x': '2023-10-10T17:03:00.000', 'person_type': 'BICYCLE', 'age': '29', 'sex': 'M', 'injury_classification': 'NONINCAPACITATING INJURY', 'pedpedal_action': 'TURNING RIGHT', 'pedpedal_visibility': 'CONTRASTING CLOTHING', 'pedpedal_location': 'BIKE LANE', 'make': 'PONTIAC', 'model': 'G6', 'vehicle_type': 'PASSENGER', 'crash_date_y': '2023-10-10T17:03:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'NO CONTROLS', 'device_condition': 'NO CONTROLS', 'weather_condition': 'CLEAR', 'lighting_condition': 'DAYLIGHT', 'first_crash_type': 'PEDALCYCLIST', 'trafficway_type': 'T-INTERSECTION', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': 'Y', 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T17:06:00.000', 'prim_contributory_cause': 'FAILING TO YIELD RIGHT-OF-WAY', 'sec_contributory_cause': 'IMPROPER TURNING/NO SIGNAL', 'street_no': '1001', 'street_direction': 'N', 'street_name': 'MARSHFIELD AVE', 'beat_of_occurrence': '1213', 'num_units': '2', 'most_severe_injury': 'NONINCAPACITATING INJURY', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '1', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '17', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.899757407', 'longitude': '-87.668457816', 'location': {'type': 'Point', 'coordinates': [-87.668457815818, 41.899757407288]}, 'intersection_related_i': 'Y', 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678854', 'crash_record_id': 'c754f73e4ef33c75c0e07ab20086c3ab5c107f9d8630706141b50bd14156a38c9e6132d68ecc428dee1d2a107b8abb1e67cd787f6c30cf6e92fabb09f331994f', 'crash_date_x': '2023-10-10T16:55:00.000', 'person_type': 'PEDESTRIAN', 'age': '21', 'sex': 'F', 'injury_classification': 'NONINCAPACITATING INJURY', 'pedpedal_action': 'CROSSING - AGAINST SIGNAL', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN ROADWAY', 'make': 'TOYOTA', 'model': 'RAV4', 'vehicle_type': 'PASSENGER', 'crash_date_y': '2023-10-10T16:55:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'TRAFFIC SIGNAL', 'device_condition': 'FUNCTIONING PROPERLY', 'weather_condition': 'CLEAR', 'lighting_condition': 'DAYLIGHT', 'first_crash_type': 'PEDESTRIAN', 'trafficway_type': 'NOT DIVIDED', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T16:55:00.000', 'prim_contributory_cause': 'UNABLE TO DETERMINE', 'sec_contributory_cause': 'NOT APPLICABLE', 'street_no': '3440', 'street_direction': 'S', 'street_name': 'ASHLAND AVE', 'beat_of_occurrence': '912', 'num_units': '2', 'most_severe_injury': 'NONINCAPACITATING INJURY', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '1', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '16', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.831105025', 'longitude': '-87.66572984', 'location': {'type': 'Point', 'coordinates': [-87.665729839757, 41.831105025379]}, 'intersection_related_i': nan, 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678771', 'crash_record_id': '819223cdae791a6347c0bd8f67ff8dce4a6d3de41879170f24e594cb0dbb91aaa5b745c5d7c60c8236f932b70e2fc98366f61e634ae5a14308a9ac5f47342388', 'crash_date_x': '2023-10-10T16:52:00.000', 'person_type': 'PEDESTRIAN', 'age': '18', 'sex': 'M', 'injury_classification': 'NO INDICATION OF INJURY', 'pedpedal_action': 'ENTER FROM DRIVE/ALLEY', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN ROADWAY', 'make': 'DODGE', 'model': 'GRAND CARAVAN', 'vehicle_type': 'VAN/MINI-VAN', 'crash_date_y': '2023-10-10T16:52:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'NO CONTROLS', 'device_condition': 'NO CONTROLS', 'weather_condition': 'CLEAR', 'lighting_condition': 'DAYLIGHT', 'first_crash_type': 'PEDESTRIAN', 'trafficway_type': 'ONE-WAY', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'ON SCENE', 'crash_type': 'NO INJURY / DRIVE AWAY', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T16:54:00.000', 'prim_contributory_cause': 'UNABLE TO DETERMINE', 'sec_contributory_cause': 'UNABLE TO DETERMINE', 'street_no': '4737', 'street_direction': 'N', 'street_name': 'HARDING AVE', 'beat_of_occurrence': '1723', 'num_units': '2', 'most_severe_injury': 'NO INDICATION OF INJURY', 'injuries_total': '0', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '0', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '2', 'injuries_unknown': '0', 'crash_hour': '16', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.967543026', 'longitude': '-87.726644552', 'location': {'type': 'Point', 'coordinates': [-87.72664455216, 41.967543026012]}, 'intersection_related_i': nan, 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678830', 'crash_record_id': '79c8cb8418200acb6bc1a64f31d7beac89e58a66704a0358f055ad083dbe6040b3be8c0eacadf8ad051275f123fab3b3851a03e87eb8b35d617ab814a668056e', 'crash_date_x': '2023-10-10T16:32:00.000', 'person_type': 'PEDESTRIAN', 'age': '13', 'sex': 'F', 'injury_classification': 'NONINCAPACITATING INJURY', 'pedpedal_action': 'CROSSING - NO CONTROLS (AT INTERSECTION)', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN CROSSWALK', 'make': 'HONDA', 'model': 'ACCORD', 'vehicle_type': 'PASSENGER', 'crash_date_y': '2023-10-10T16:32:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'NO CONTROLS', 'device_condition': 'NO CONTROLS', 'weather_condition': 'CLEAR', 'lighting_condition': 'DAYLIGHT', 'first_crash_type': 'PEDESTRIAN', 'trafficway_type': 'FOUR WAY', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T16:32:00.000', 'prim_contributory_cause': 'FAILING TO YIELD RIGHT-OF-WAY', 'sec_contributory_cause': 'FAILING TO YIELD RIGHT-OF-WAY', 'street_no': '4100', 'street_direction': 'N', 'street_name': 'ASHLAND AVE', 'beat_of_occurrence': '1912', 'num_units': '2', 'most_severe_injury': 'NONINCAPACITATING INJURY', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '1', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '2', 'injuries_unknown': '0', 'crash_hour': '16', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.956216672', 'longitude': '-87.669249102', 'location': {'type': 'Point', 'coordinates': [-87.669249101648, 41.956216671811]}, 'intersection_related_i': 'Y', 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678741', 'crash_record_id': 'f71d845188193768fb38fc4af4595f43d262daa829dec10b932baa4d15efb4d19034888930729f5071e12bf7401534321e1a7e861327f15ab4bb3a16658bc4ce', 'crash_date_x': '2023-10-10T16:10:00.000', 'person_type': 'PEDESTRIAN', 'age': '80', 'sex': 'F', 'injury_classification': 'NONINCAPACITATING INJURY', 'pedpedal_action': 'CROSSING - AGAINST SIGNAL', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN CROSSWALK', 'make': 'NISSAN', 'model': 'MAXIMA', 'vehicle_type': 'PASSENGER', 'crash_date_y': '2023-10-10T16:10:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'TRAFFIC SIGNAL', 'device_condition': 'FUNCTIONING PROPERLY', 'weather_condition': 'CLEAR', 'lighting_condition': 'DAYLIGHT', 'first_crash_type': 'PEDESTRIAN', 'trafficway_type': 'NOT DIVIDED', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': '$500 OR LESS', 'date_police_notified': '2023-10-10T16:10:00.000', 'prim_contributory_cause': 'DISREGARDING TRAFFIC SIGNALS', 'sec_contributory_cause': 'NOT APPLICABLE', 'street_no': '6300', 'street_direction': 'S', 'street_name': 'CICERO AVE', 'beat_of_occurrence': '813', 'num_units': '2', 'most_severe_injury': 'NONINCAPACITATING INJURY', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '1', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '16', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.77833539', 'longitude': '-87.742436494', 'location': {'type': 'Point', 'coordinates': [-87.74243649416, 41.778335390453]}, 'intersection_related_i': nan, 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1679018', 'crash_record_id': '72d38eec84431b3a30b59984d7748c2ff4c5d89fc0abb4cc78ea4b5d004d5caf13066d3e5b5f6fe13f961c2e55da101cc637e42fe1a0c3f85447d187c6fad7d1', 'crash_date_x': '2023-10-10T10:46:00.000', 'person_type': 'BICYCLE', 'age': '28', 'sex': 'M', 'injury_classification': 'NONINCAPACITATING INJURY', 'pedpedal_action': 'CROSSING - NO CONTROLS (AT INTERSECTION)', 'pedpedal_visibility': 'CONTRASTING CLOTHING', 'pedpedal_location': 'IN ROADWAY', 'make': 'UNKNOWN', 'model': 'OTHER (EXPLAIN IN NARRATIVE)', 'vehicle_type': 'UNKNOWN/NA', 'crash_date_y': '2023-10-10T10:46:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'TRAFFIC SIGNAL', 'device_condition': 'FUNCTIONING IMPROPERLY', 'weather_condition': 'CLEAR', 'lighting_condition': 'DAYLIGHT', 'first_crash_type': 'PEDALCYCLIST', 'trafficway_type': 'ONE-WAY', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'NOT ON SCENE (DESK REPORT)', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': '$501 - $1,500', 'date_police_notified': '2023-10-10T22:00:00.000', 'prim_contributory_cause': 'UNABLE TO DETERMINE', 'sec_contributory_cause': 'NOT APPLICABLE', 'street_no': '1', 'street_direction': 'N', 'street_name': 'DESPLAINES ST', 'beat_of_occurrence': '121', 'num_units': '2', 'most_severe_injury': 'NONINCAPACITATING INJURY', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '1', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '10', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.881857203', 'longitude': '-87.643981876', 'location': {'type': 'Point', 'coordinates': [-87.643981875883, 41.881857203001]}, 'intersection_related_i': 'Y', 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678554', 'crash_record_id': 'a034d430254a5dcd37ce994241de9978b0f1cb2fee2b1f880f85a4c5ecb1f09f08ad62f12148cf83181ae8d8d84d175c907cccc3ea5cebd231b2002b1b253fb0', 'crash_date_x': '2023-10-10T10:30:00.000', 'person_type': 'PEDESTRIAN', 'age': '24', 'sex': 'M', 'injury_classification': 'REPORTED, NOT EVIDENT', 'pedpedal_action': 'WITH TRAFFIC', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN ROADWAY', 'make': 'BMW', 'model': 'X5', 'vehicle_type': 'SPORT UTILITY VEHICLE (SUV)', 'crash_date_y': '2023-10-10T10:30:00.000', 'posted_speed_limit': '15', 'traffic_control_device': 'NO CONTROLS', 'device_condition': 'NO CONTROLS', 'weather_condition': 'CLEAR', 'lighting_condition': 'DAYLIGHT', 'first_crash_type': 'PEDESTRIAN', 'trafficway_type': 'PARKING LOT', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': 'Y', 'hit_and_run_i': nan, 'damage': '$500 OR LESS', 'date_police_notified': '2023-10-10T10:34:00.000', 'prim_contributory_cause': 'FAILING TO YIELD RIGHT-OF-WAY', 'sec_contributory_cause': 'NOT APPLICABLE', 'street_no': '711', 'street_direction': 'W', 'street_name': 'JACKSON BLVD', 'beat_of_occurrence': '121', 'num_units': '2', 'most_severe_injury': 'REPORTED, NOT EVIDENT', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '0', 'injuries_reported_not_evident': '1', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '10', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.877871739', 'longitude': '-87.64450946', 'location': {'type': 'Point', 'coordinates': [-87.644509459649, 41.877871738632]}, 'intersection_related_i': nan, 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678413', 'crash_record_id': '966cde65d4209ca38cc9975b122434355ab7ccbd23b4349669ec49a65cb13b65280196a770c973c0600b0443429f33d7643146188dec7f39cd871195225ae821', 'crash_date_x': '2023-10-10T07:30:00.000', 'person_type': 'PEDESTRIAN', 'age': '72', 'sex': 'M', 'injury_classification': 'NONINCAPACITATING INJURY', 'pedpedal_action': 'NOT AT INTERSECTION', 'pedpedal_visibility': 'NO CONTRASTING CLOTHING', 'pedpedal_location': 'IN ROADWAY', 'make': 'UNKNOWN', 'model': 'OTHER (EXPLAIN IN NARRATIVE)', 'vehicle_type': 'PASSENGER', 'crash_date_y': '2023-10-10T07:30:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'NO CONTROLS', 'device_condition': 'UNKNOWN', 'weather_condition': 'CLEAR', 'lighting_condition': 'DAYLIGHT', 'first_crash_type': 'PEDESTRIAN', 'trafficway_type': 'ONE-WAY', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'UNKNOWN', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T08:07:00.000', 'prim_contributory_cause': 'UNABLE TO DETERMINE', 'sec_contributory_cause': 'UNABLE TO DETERMINE', 'street_no': '4920', 'street_direction': 'N', 'street_name': 'KENMORE AVE', 'beat_of_occurrence': '2024', 'num_units': '2', 'most_severe_injury': 'NONINCAPACITATING INJURY', 'injuries_total': '2', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '2', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '0', 'injuries_unknown': '0', 'crash_hour': '7', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.972200503', 'longitude': '-87.65644765', 'location': {'type': 'Point', 'coordinates': [-87.656447650479, 41.972200503121]}, 'intersection_related_i': nan, 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# {'person_id': 'O1678329', 'crash_record_id': '99cd17dc5d5860c81cf72b1964c1f103a04d8621d525dc4e9e309ec2c0a309f6e1fab888a3df662a46a0cbe64094cb277b0c273a26a13ef56b31f26e276609a9', 'crash_date_x': '2023-10-10T05:20:00.000', 'person_type': 'BICYCLE', 'age': '31', 'sex': 'M', 'injury_classification': 'NONINCAPACITATING INJURY', 'pedpedal_action': 'CROSSING - WITH SIGNAL', 'pedpedal_visibility': 'OTHER LIGHT SOURCE USED', 'pedpedal_location': 'IN CROSSWALK', 'make': 'NISSAN', 'model': 'SENTRA', 'vehicle_type': 'PASSENGER', 'crash_date_y': '2023-10-10T05:20:00.000', 'posted_speed_limit': '30', 'traffic_control_device': 'TRAFFIC SIGNAL', 'device_condition': 'FUNCTIONING PROPERLY', 'weather_condition': 'CLEAR', 'lighting_condition': 'DUSK', 'first_crash_type': 'PEDALCYCLIST', 'trafficway_type': 'FOUR WAY', 'alignment': 'STRAIGHT AND LEVEL', 'roadway_surface_cond': 'DRY', 'road_defect': 'NO DEFECTS', 'report_type': 'ON SCENE', 'crash_type': 'INJURY AND / OR TOW DUE TO CRASH', 'private_property_i': nan, 'hit_and_run_i': nan, 'damage': 'OVER $1,500', 'date_police_notified': '2023-10-10T05:26:00.000', 'prim_contributory_cause': 'FAILING TO YIELD RIGHT-OF-WAY', 'sec_contributory_cause': 'NOT APPLICABLE', 'street_no': '9499', 'street_direction': 'S', 'street_name': 'WESTERN AVE', 'beat_of_occurrence': '2221', 'num_units': '2', 'most_severe_injury': 'NONINCAPACITATING INJURY', 'injuries_total': '1', 'injuries_fatal': '0', 'injuries_incapacitating': '0', 'injuries_non_incapacitating': '1', 'injuries_reported_not_evident': '0', 'injuries_no_indication': '1', 'injuries_unknown': '0', 'crash_hour': '5', 'crash_day_of_week': '3', 'crash_month': '10', 'latitude': '41.721032187', 'longitude': '-87.681921394', 'location': {'type': 'Point', 'coordinates': [-87.681921394113, 41.721032187113]}, 'intersection_related_i': 'Y', 'photos_taken_i': nan, 'crash_date_est_i': nan, 'statements_taken_i': nan, 'work_zone_i': nan, 'work_zone_type': nan, 'workers_present_i': nan}
# 2023-10-11 18:46:43.410098
# 2023-10-11 18:46:43.412738
# 2023-10-11 18:46:43.415333
# 2023-10-11 18:46:43.417440
# 2023-10-11 18:46:43.419469
# 2023-10-11 18:46:43.421926
# 2023-10-11 18:46:43.424038
# 2023-10-11 18:46:43.435493
# 2023-10-11 18:46:43.437882
# 2023-10-11 18:46:43.440028
# 2023-10-11 18:46:43.441543
# 2023-10-11 18:46:43.443278
# 2023-10-11 18:46:43.445632
# 2023-10-11 18:46:43.447784
# 2023-10-11 18:46:43.450131
# 2023-10-11 18:46:43.452387
